# %% [markdown]
# The following example shows how to generate training data. We want to train the drone flying in y-z plane with different wall distance.
# Notes:
# - Turn off disturbance observer is not a requirement. Any given controller output can correspond to a disturbance force.
# - Run the scenario in simulation_user_guide.ipynb first to make sure the drone does not hit the wall. Adjust wall distance from performance.
# - Use the same trajectory in every condition as the same setting in Neural Fly paper.
# - Use RandomWaypointsInConstrainedSpace to fly in a constrained 3D space in front of a wall.
# - When training disturbance model with inflow model in controller, enable inflow model option in controller.
# - Use baseline disturbacne observer to generate training data.
# - Ensure the disturbance model is set to the correct condition, i.e. setting of sinusoidal wind
# - restart the ipynb before run

# %% [markdown]
# Set up configs of different use cases: ML data for training or validation, data for pure fitting

# %%
import sys
import os
import numpy as np

# Get the current directory of the notebook
notebook_dir = os.getcwd()

# Add the parent directory to sys.path
parent_dir = os.path.abspath(os.path.join(notebook_dir, '..'))
if parent_dir not in sys.path:
    sys.path.append(parent_dir)

import manager
import drone.disturbance_model
import drone.trajectory

def extra_format(value):
    val = abs(value)
    s = f"{val:.1f}".replace('.', '_')
    return f"n{s}" if value < 0 else s

config_template = {
    "t_data_collection": None,
    "file_name_template": None,
    "wall_distance_range": None,
    "wind_range_x": None,
    "wind_range_y": None,
    "wind_range_z": None,
    "is_csv": False,
    "trajectory": None,
}

training_trajectory = drone.trajectory.RandomWaypointsInConstrainedSpace(200, False)
validation_trajectory = drone.trajectory.Figure8(20)
validation_trajectory2 = drone.trajectory.CircleYZ()


training_config = config_template.copy()
training_config["t_data_collection"] = 20.0
training_config["file_name_template"] = "test_wind_near_wall_x{}_y{}_z{}_d{}_train_no_bemt"
training_config["wall_distance_range"] = [0.1]  # in a constrained space, the wall distance naturally varies, so there is no need to set multiple values
training_config["wall_distance_range"] = [100]  # use large value to simulate no wall
training_config["wind_range_x"] = [-3.0, -1.0, 0.0]
training_config["wind_range_y"] = [0.0]
training_config["wind_range_z"] = [-5.0, -3.0, 0.0, 3.0, 5.0]
training_config["is_csv"] = True
training_config["trajectory"] = training_trajectory

validation_config = config_template.copy()
validation_config["t_data_collection"] = 10.0
validation_config["file_name_template"] = "test_wind_near_wall_x{}_y{}_z{}_d{}_validation_no_bemt"
validation_config["wall_distance_range"] = [1.0]  # in a constrained space, the wall distance naturally varies, so there is no need to set multiple values
validation_config["wind_range_x"] = [-5.0, -2.0, 0.0]
validation_config["wind_range_y"] = [0.0]
validation_config["wind_range_z"] = [-4.0, -1.0, 1.0, 4.0]
validation_config["is_csv"] = True
validation_config["trajectory"] = validation_trajectory

fitting_config = config_template.copy()
fitting_config["t_data_collection"] = 15.0
fitting_config["file_name_template"] = "test_wind_near_wall_x{}_y{}_z{}_d{}_fitting"
fitting_config["wall_distance_range"] = [100.0]  # in case need to treat as no wall

# fitting use
# fitting_config["wind_range_x"] = [-3.0, 0.0]
# fitting_config["wind_range_y"] = [0.0]
# fitting_config["wind_range_z"] = [-5.0, 0.0, 5.0]

# training use
fitting_config["wind_range_x"] = [-3.0, -1.0, 0.0]
fitting_config["wind_range_y"] = [0.0]
fitting_config["wind_range_z"] = [-5.0, -3.0, 0.0, 3.0, 5.0]

# training use (extended range)
# fitting_config["wind_range_x"] = [-4.0, -3.0, -1.0, 0.0]
# fitting_config["wind_range_y"] = [0.0]
# fitting_config["wind_range_z"] = [-7.0, -5.0, -3.0, 0.0, 3.0, 5.0, 7.0]
fitting_config["is_csv"] = True
fitting_config["trajectory"] = training_trajectory

fitting_validation_config = config_template.copy()
fitting_validation_config["t_data_collection"] = 40.0
fitting_validation_config["file_name_template"] = "test_wind_near_wall_x{}_y{}_z{}_d{}_validation"
fitting_validation_config["wall_distance_range"] = [0.1]  # in a constrained space, the wall distance naturally varies, so there is no need to set multiple values
# fitting_validation_config["wind_range_x"] = [-5.0, -2.0, 0.0]
# fitting_validation_config["wind_range_y"] = [0.0]
# fitting_validation_config["wind_range_z"] = [-10.0, -4.0, -1.0, 1.0, 4.0, 10.0]
# new trial
fitting_validation_config["wind_range_x"] = [-10.0, -8.0, -5.0, -2.0, 0.0]
fitting_validation_config["wind_range_y"] = [0.0]
fitting_validation_config["wind_range_z"] = [0.0]
fitting_validation_config["is_csv"] = True
# fitting_validation_config["trajectory"] = validation_trajectory
fitting_validation_config["trajectory"] = validation_trajectory2

fitting_far_from_wall_validation_config = config_template.copy()
fitting_far_from_wall_validation_config["t_data_collection"] = 40.0
fitting_far_from_wall_validation_config["file_name_template"] = "test_wind_far_from_wall_x{}_y{}_z{}_d{}_validation"
fitting_far_from_wall_validation_config["wall_distance_range"] = [100.0]  # in a constrained space, the wall distance naturally varies, so there is no need to set multiple values
# fitting_far_from_wall_validation_config["wind_range_x"] = [-5.0, -2.0, 0.0]
# fitting_far_from_wall_validation_config["wind_range_y"] = [0.0]
# fitting_far_from_wall_validation_config["wind_range_z"] = [-10.0, -4.0, -1.0, 1.0, 4.0, 10.0]
# new trial
fitting_far_from_wall_validation_config["wind_range_x"] = [-10.0, -8.0, -5.0, -2.0, 0.0]
fitting_far_from_wall_validation_config["wind_range_y"] = [0.0]
fitting_far_from_wall_validation_config["wind_range_z"] = [0.0]
fitting_far_from_wall_validation_config["is_csv"] = True
# fitting_far_from_wall_validation_config["trajectory"] = validation_trajectory
fitting_far_from_wall_validation_config["trajectory"] = validation_trajectory2
# Out:
# Map data read from: ..\data\map\figure_8.pkl
# Map data read from: ..\data\map\figure_8.pkl
# Map data read from: ..\data\map\figure_8.pkl
# Map data read from: ..\data\map\figure_8.pkl
# Map data read from: ..\data\map\figure_8.pkl
# Map data read from: ..\data\map\figure_8.pkl
# Map data read from: ..\data\map\figure_8.pkl
# Map data read from: ..\data\map\figure_8.pkl
# Map data read from: ..\data\map\figure_8.pkl
# Map data read from: ..\data\map\figure_8.pkl
# Map data read from: ..\data\map\figure_8.pkl
# Map data read from: ..\data\map\figure_8.pkl
# Map data read from: ..\data\map\figure_8.pkl
# Map data read from: ..\data\map\figure_8.pkl
# Map data read from: ..\data\map\figure_8.pkl
# Map data read from: ..\data\map\figure_8.pkl
# Map data read from: ..\data\map\figure_8.pkl
# Map data read from: ..\data\map\figure_8.pkl
# Map data read from: ..\data\map\figure_8.pkl
# Map data read from: ..\data\map\figure_8.pkl

# %% [markdown]
# Run to generate training data.

# %%
selected_config = validation_config  # Change this to training_config, validation_config, fitting_config, or fitting_validation_config as needed


x_position_error = 0.4  # accounting for controller error to prevent collision to the wall
wall_distance_range = [distance + x_position_error for distance in selected_config["wall_distance_range"]]

is_csv = selected_config["is_csv"]  # save as csv file
for wall_distance in wall_distance_range:
    for wind_speed_x in selected_config["wind_range_x"]:
        for wind_speed_y in selected_config["wind_range_y"]:
            for wind_speed_z in selected_config["wind_range_z"]:
                print(f"Running simulation with wind speed ({wind_speed_x}, {wind_speed_y}, {wind_speed_z}) and wall distance {wall_distance}")
                # Initialize the simulation manager
                sim_test = manager.Manager()
                model = drone.disturbance_model.WindEffectNearWall(wall_origin=np.array([-wall_distance, 0, 0]), 
                                                                u_free = np.array([wind_speed_x, wind_speed_y, wind_speed_z]))
                # model = drone.disturbance_model.Free()    # debug only
                # trajectory=drone.trajectory.RandomWaypointsInConstrainedSpace(200, False)
                trajectory = selected_config["trajectory"]
                sim_test.set_up(disturbance_model=model, trajectory=trajectory)
                sim_test.run(selected_config["t_data_collection"]) 
                
                # Save the result
                file_name = selected_config["file_name_template"].format(extra_format(wind_speed_x), 
                                                    extra_format(wind_speed_y),
                                                    extra_format(wind_speed_z),
                                                    extra_format(wall_distance))
                if is_csv:
                    sim_test.save_result_as_csv(file_name)
                else:
                    sim_test.save_result_as_pkl(file_name)
# Out:
# Running simulation with wind speed (-5.0, 0.0, -4.0) and wall distance 1.4
# [PropellerLookupTable] Reading data from ..\inflow_model\lookup_table\p600_full_range.yaml
# is_sinusoidal_wind:  False
# DroneController: using inflow model:  True
# DroneController: using pure DIAML disturbance estimator:  False
# DroneController: using baseline disturbance estimator:  False
# DroneController: using BEMT disturbance estimator:  True
# phi net input output fields:
# input {'position': [0, 1, 2], 'q': [0, 1, 2, 3], 'v': [0, 1, 2], 'sensed_omega': [0, 1, 2], 'f_ctrl_input': [2], 'torque_ctrl_input': [0, 1, 2], 'rotor_0_rotation_spd': None, 'rotor_1_rotation_spd': None, 'rotor_2_rotation_spd': None, 'rotor_3_rotation_spd': None}
# label {'f_disturb_sensed_raw': [0, 1, 2]}
# simple net input output fields:
# input {'q': [0, 1, 2, 3], 'v': [0, 1, 2], 'sensed_omega': [0, 1, 2], 'rotor_0_local_wind_velocity': [0, 1, 2], 'rotor_1_local_wind_velocity': [0, 1, 2], 'rotor_2_local_wind_velocity': [0, 1, 2], 'rotor_3_local_wind_velocity': [0, 1, 2], 'rotor_0_rotation_spd': None, 'rotor_1_rotation_spd': None, 'rotor_2_rotation_spd': None, 'rotor_3_rotation_spd': None}
# shared_input {'q': [0, 1, 2, 3], 'v': [0, 1, 2], 'sensed_omega': [0, 1, 2]}
# individual_input [{'rotor_0_local_wind_velocity': [0, 1, 2], 'rotor_0_rotation_spd': None}, {'rotor_1_local_wind_velocity': [0, 1, 2], 'rotor_1_rotation_spd': None}, {'rotor_2_local_wind_velocity': [0, 1, 2], 'rotor_2_rotation_spd': None}, {'rotor_3_local_wind_velocity': [0, 1, 2], 'rotor_3_rotation_spd': None}]
# label {'f_residual': [0, 1, 2]}
# [PropellerLookupTable] Reading data from ..\inflow_model\lookup_table\p600_full_range.yaml
# number of controller steps per simulation step: 1
# number of dynamics model steps per controller step: 2
# check output force:  [3.63992242 3.68170844 3.64647494 3.68390689]
# desired rotor speed: [213.41720761 214.48940016 213.58533949 214.54581053]
# controller output torque:  [-0.00185634 -0.00092363  0.00147128]
# controller output speed:  [213.41720761 214.48940016 213.58533949 214.54581053]
# controller output torque:  [-0.00185634 -0.00092363  0.00147128]
# controller output speed:  [213.41720761 214.48940016 213.58533949 214.54581053]
# controller output torque:  [-0.00185634 -0.00092363  0.00147128]
# controller output speed:  [213.41720761 214.48940016 213.58533949 214.54581053]
# check output force:  [4.66200938 4.92376542 4.9636914  4.68481525]
# desired rotor speed: [308.45734376 314.57703083 315.42592659 308.94233563]
# controller output torque:  [-0.01330731 -0.11468431 -0.00031797]
# controller output speed:  [308.45734376 314.57703083 315.42592659 308.94233563]
# controller output torque:  [-0.01330731 -0.11468431 -0.00031797]
# controller output speed:  [308.45734376 314.57703083 315.42592659 308.94233563]
# controller output torque:  [-0.01330731 -0.11468431 -0.00031797]
# controller output speed:  [308.45734376 314.57703083 315.42592659 308.94233563]
# check output force:  [5.75595262 6.39831343 6.67238207 5.88658606]
# desired rotor speed: [329.78160391 343.57623572 349.36608073 332.5395724 ]
# controller output torque:  [-0.08584945 -0.30295491 -0.00266397]
# controller output speed:  [329.78160391 343.57623572 349.36608073 332.5395724 ]
# controller output torque:  [-0.08584945 -0.30295491 -0.00266397]
# controller output speed:  [329.78160391 343.57623572 349.36608073 332.5395724 ]
# controller output torque:  [-0.08584945 -0.30295491 -0.00266397]
# controller output speed:  [329.78160391 343.57623572 349.36608073 332.5395724 ]
# check output force:  [6.70988184 7.61045952 8.00274298 6.93832268]
# desired rotor speed: [348.12956838 366.98124294 375.24892423 352.94530594]
# controller output torque:  [-0.13167425 -0.41683502 -0.00304298]
# controller output speed:  [348.12956838 366.98124294 375.24892423 352.94530594]
# controller output torque:  [-0.13167425 -0.41683502 -0.00304298]
# controller output speed:  [348.12956838 366.98124294 375.24892423 352.94530594]
# controller output torque:  [-0.13167425 -0.41683502 -0.00304298]
# controller output speed:  [348.12956838 366.98124294 375.24892423 352.94530594]
# check output force:  [7.45203633 8.69084443 9.01791737 7.72991609]
# desired rotor speed: [362.03983531 387.62124448 394.52451913 367.90508404]
# controller output torque:  [-0.12832861 -0.53601207 -0.00091365]
# controller output speed:  [362.03983531 387.62124448 394.52451913 367.90508404]
# controller output torque:  [-0.12832861 -0.53601207 -0.00091365]
# controller output speed:  [362.03983531 387.62124448 394.52451913 367.90508404]
# controller output torque:  [-0.12832861 -0.53601207 -0.00091365]
# controller output speed:  [362.03983531 387.62124448 394.52451913 367.90508404]
# check output force:  [8.03410287 9.62542783 9.7996978  8.28707196]
# desired rotor speed: [372.64060058 403.99936459 406.84038273 378.01362709]
# controller output torque:  [-0.09063022 -0.65844108  0.00146165]
# controller output speed:  [372.64060058 403.99936459 406.84038273 378.01362709]
# controller output torque:  [-0.09063022 -0.65844108  0.00146165]
# controller output speed:  [372.64060058 403.99936459 406.84038273 378.01362709]
# controller output torque:  [-0.09063022 -0.65844108  0.00146165]
# controller output speed:  [372.64060058 403.99936459 406.84038273 378.01362709]
# check output force:  [ 8.50168796 10.4061843  10.46176233  8.69662841]
# desired rotor speed: [380.91846858 415.04995209 416.04446126 385.12130119]
# controller output torque:  [-0.05314248 -0.77843867  0.00258832]
# controller output speed:  [380.91846858 415.04995209 416.04446126 385.12130119]
# controller output torque:  [-0.05314248 -0.77843867  0.00258832]
# controller output speed:  [380.91846858 415.04995209 416.04446126 385.12130119]
# controller output torque:  [-0.05314248 -0.77843867  0.00258832]
# controller output speed:  [380.91846858 415.04995209 416.04446126 385.12130119]
# check output force:  [ 8.91215171 11.04143887 11.06740603  9.03088443]
# desired rotor speed: [388.09071705 423.89955175 424.46701489 390.75383728]
# controller output torque:  [-0.03069519 -0.88369301  0.0017229 ]
# controller output speed:  [388.09071705 423.89955175 424.46701489 390.75383728]
# controller output torque:  [-0.03069519 -0.88369301  0.0017229 ]
# controller output speed:  [388.09071705 423.89955175 424.46701489 390.75383728]
# controller output torque:  [-0.03069519 -0.88369301  0.0017229 ]
# controller output speed:  [388.09071705 423.89955175 424.46701489 390.75383728]
# check output force:  [ 9.27846037 11.55964858 11.60154095  9.34015312]
# desired rotor speed: [394.42815575 431.02384358 431.88758832 395.95868872]
# controller output torque:  [-2.19735120e-02 -9.63616657e-01  3.67744688e-04]
# controller output speed:  [394.42815575 431.02384358 431.88758832 395.95868872]
# controller output torque:  [-2.19735120e-02 -9.63616657e-01  3.67744688e-04]
# controller output speed:  [394.42815575 431.02384358 431.88758832 395.95868872]
# controller output torque:  [-2.19735120e-02 -9.63616657e-01  3.67744688e-04]
# controller output speed:  [394.42815575 431.02384358 431.88758832 395.95868872]
# check output force:  [ 9.6182143  11.96820844 11.98260499  9.62989233]
# desired rotor speed: [400.20065671 436.61014192 437.08902907 400.6230242 ]
# controller output torque:  [-5.53120193e-03 -9.97585194e-01 -5.04899415e-05]
# controller output speed:  [400.20065671 436.61014192 437.08902907 400.6230242 ]
# controller output torque:  [-5.53120193e-03 -9.97585194e-01 -5.04899415e-05]
# controller output speed:  [400.20065671 436.61014192 437.08902907 400.6230242 ]
# controller output torque:  [-5.53120193e-03 -9.97585194e-01 -5.04899415e-05]
# controller output speed:  [400.20065671 436.61014192 437.08902907 400.6230242 ]
# check output force:  [ 9.88479343 12.3004393  12.20706066  9.84053818]
# desired rotor speed: [403.6060569  441.19058878 440.02239621 403.19470761]
# controller output torque:  [ 2.91962753e-02 -1.01444137e+00  9.12349379e-04]
# controller output speed:  [403.6060569  441.19058878 440.02239621 403.19470761]
# controller output torque:  [ 2.91962753e-02 -1.01444137e+00  9.12349379e-04]
# controller output speed:  [403.6060569  441.19058878 440.02239621 403.19470761]
# controller output torque:  [ 2.91962753e-02 -1.01444137e+00  9.12349379e-04]
# controller output speed:  [403.6060569  441.19058878 440.02239621 403.19470761]
# check output force:  [10.07803487 12.54932846 12.3147715   9.96279651]
# desired rotor speed: [405.99631864 444.65374422 441.30538676 404.50704782]
# controller output torque:  [ 0.07420208 -1.02315996  0.00221606]
# controller output speed:  [405.99631864 444.65374422 441.30538676 404.50704782]
# controller output torque:  [ 0.07420208 -1.02315996  0.00221606]
# controller output speed:  [405.99631864 444.65374422 441.30538676 404.50704782]
# controller output torque:  [ 0.07420208 -1.02315996  0.00221606]
# controller output speed:  [405.99631864 444.65374422 441.30538676 404.50704782]
# check output force:  [10.21840337 12.69884691 12.39022821 10.02223753]
# desired rotor speed: [407.69500808 446.74307367 442.25978489 404.96026731]
# controller output torque:  [ 0.10707994 -1.02849835  0.00208854]
# controller output speed:  [407.69500808 446.74307367 442.25978489 404.96026731]
# controller output torque:  [ 0.10707994 -1.02849835  0.00208854]
# controller output speed:  [407.69500808 446.74307367 442.25978489 404.96026731]
# controller output torque:  [ 0.10707994 -1.02849835  0.00208854]
# controller output speed:  [407.69500808 446.74307367 442.25978489 404.96026731]
# check output force:  [10.34921923 12.74763428 12.49438155 10.06723438]
# desired rotor speed: [409.38177928 447.43024351 443.83348344 405.31064578]
# controller output torque:  [ 1.13539951e-01 -1.02364651e+00 -5.33630364e-04]
# controller output speed:  [409.38177928 447.43024351 443.83348344 405.31064578]
# controller output torque:  [ 1.13539951e-01 -1.02364651e+00 -5.33630364e-04]
# controller output speed:  [409.38177928 447.43024351 443.83348344 405.31064578]
# controller output torque:  [ 1.13539951e-01 -1.02364651e+00 -5.33630364e-04]
# controller output speed:  [409.38177928 447.43024351 443.83348344 405.31064578]
# check output force:  [10.48563738 12.71429854 12.62586238 10.15824961]
# desired rotor speed: [411.29042756 446.99772224 445.99426838 406.50421487]
# controller output torque:  [ 0.08820873 -0.99622059 -0.00443795]
# controller output speed:  [411.29042756 446.99772224 445.99426838 406.50421487]
# controller output torque:  [ 0.08820873 -0.99622059 -0.00443795]
# controller output speed:  [411.29042756 446.99772224 445.99426838 406.50421487]
# controller output torque:  [ 0.08820873 -0.99622059 -0.00443795]
# controller output speed:  [411.29042756 446.99772224 445.99426838 406.50421487]
# check output force:  [10.60414365 12.6547645  12.7091818  10.29944858]
# desired rotor speed: [413.04633155 446.31208888 447.54466186 408.60406631]
# controller output torque:  [ 0.05309142 -0.94617491 -0.00666965]
# controller output speed:  [413.04633155 446.31208888 447.54466186 408.60406631]
# controller output torque:  [ 0.05309142 -0.94617491 -0.00666965]
# controller output speed:  [413.04633155 446.31208888 447.54466186 408.60406631]
# controller output torque:  [ 0.05309142 -0.94617491 -0.00666965]
# controller output speed:  [413.04633155 446.31208888 447.54466186 408.60406631]
# check output force:  [10.67470141 12.60326775 12.66638645 10.42798277]
# desired rotor speed: [414.17285956 445.89726185 447.24688043 410.62239444]
# controller output torque:  [ 0.03894705 -0.88393935 -0.00575449]
# controller output speed:  [414.17285956 445.89726185 447.24688043 410.62239444]
# controller output torque:  [ 0.03894705 -0.88393935 -0.00575449]
# controller output speed:  [414.17285956 445.89726185 447.24688043 410.62239444]
# controller output torque:  [ 0.03894705 -0.88393935 -0.00575449]
# controller output speed:  [414.17285956 445.89726185 447.24688043 410.62239444]
# check output force:  [10.66434798 12.5657115  12.47107333 10.46138668]
# desired rotor speed: [414.1473847  445.83189575 444.67011484 411.26177   ]
# controller output torque:  [ 0.06312978 -0.82965107 -0.00201184]
# controller output speed:  [414.1473847  445.83189575 444.67011484 411.26177   ]
# controller output torque:  [ 0.06312978 -0.82965107 -0.00201184]
# controller output speed:  [414.1473847  445.83189575 444.67011484 411.26177   ]
# controller output torque:  [ 0.06312978 -0.82965107 -0.00201184]
# controller output speed:  [414.1473847  445.83189575 444.67011484 411.26177   ]
# check output force:  [10.56596809 12.51313901 12.17939868 10.35695404]
# desired rotor speed: [412.85209005 445.6465858  440.68075808 409.84377611]
# controller output torque:  [ 0.11513449 -0.79964855  0.00231649]
# controller output speed:  [412.85209005 445.6465858  440.68075808 409.84377611]
# controller output torque:  [ 0.11513449 -0.79964855  0.00231649]
# controller output speed:  [412.85209005 445.6465858  440.68075808 409.84377611]
# controller output torque:  [ 0.11513449 -0.79964855  0.00231649]
# controller output speed:  [412.85209005 445.6465858  440.68075808 409.84377611]
# check output force:  [10.42139996 12.40016611 11.91250868 10.12241295]
# desired rotor speed: [410.9365644  444.61262766 437.17249124 406.47576665]
# controller output torque:  [ 0.16687089 -0.79948867  0.0035041 ]
# controller output speed:  [410.9365644  444.61262766 437.17249124 406.47576665]
# controller output torque:  [ 0.16687089 -0.79948867  0.0035041 ]
# controller output speed:  [410.9365644  444.61262766 437.17249124 406.47576665]
# controller output torque:  [ 0.16687089 -0.79948867  0.0035041 ]
# controller output speed:  [410.9365644  444.61262766 437.17249124 406.47576665]
# check output force:  [10.27114444 12.19414408 11.74727806  9.87944561]
# desired rotor speed: [409.02451886 442.21344358 435.35379169 403.04704095]
# controller output torque:  [ 0.17788476 -0.80414921  0.0010246 ]
# controller output speed:  [409.02451886 442.21344358 435.35379169 403.04704095]
# controller output torque:  [ 0.17788476 -0.80414921  0.0010246 ]
# controller output speed:  [409.02451886 442.21344358 435.35379169 403.04704095]
# controller output torque:  [ 0.17788476 -0.80414921  0.0010246 ]
# controller output speed:  [409.02451886 442.21344358 435.35379169 403.04704095]
# check output force:  [10.16574032 11.90353312 11.69454108  9.71569114]
# desired rotor speed: [407.89352666 438.58223854 435.4087907  400.92129543]
# controller output torque:  [ 0.13980241 -0.78841143 -0.00447706]
# controller output speed:  [407.89352666 438.58223854 435.4087907  400.92129543]
# controller output torque:  [ 0.13980241 -0.78841143 -0.00447706]
# controller output speed:  [407.89352666 438.58223854 435.4087907  400.92129543]
# controller output torque:  [ 0.13980241 -0.78841143 -0.00447706]
# controller output speed:  [407.89352666 438.58223854 435.4087907  400.92129543]
# check output force:  [10.09758124 11.58183804 11.67362634  9.69081781]
# desired rotor speed: [407.42038821 434.54861203 436.05844208 401.04386364]
# controller output torque:  [ 0.06681567 -0.73546857 -0.00925941]
# controller output speed:  [407.42038821 434.54861203 436.05844208 401.04386364]
# controller output torque:  [ 0.06681567 -0.73546857 -0.00925941]
# controller output speed:  [407.42038821 434.54861203 436.05844208 401.04386364]
# controller output torque:  [ 0.06681567 -0.73546857 -0.00925941]
# controller output speed:  [407.42038821 434.54861203 436.05844208 401.04386364]
# check output force:  [10.04451847 11.28462611 11.57897313  9.75116345]
# desired rotor speed: [407.25237318 430.97695554 435.62347292 402.57953276]
# controller output torque:  [-2.10435291e-04 -6.50797301e-01 -1.09151591e-02]
# controller output speed:  [407.25237318 430.97695554 435.62347292 402.57953276]
# controller output torque:  [-2.10435291e-04 -6.50797301e-01 -1.09151591e-02]
# controller output speed:  [407.25237318 430.97695554 435.62347292 402.57953276]
# controller output torque:  [-2.10435291e-04 -6.50797301e-01 -1.09151591e-02]
# controller output speed:  [407.25237318 430.97695554 435.62347292 402.57953276]
# check output force:  [ 9.95057928 11.04844215 11.34404573  9.80089963]
# desired rotor speed: [406.50258535 428.43419548 433.03304631 404.02537433]
# controller output torque:  [-0.03095484 -0.56023723 -0.00827007]
# controller output speed:  [406.50258535 428.43419548 433.03304631 404.02537433]
# controller output torque:  [-0.03095484 -0.56023723 -0.00827007]
# controller output speed:  [406.50258535 428.43419548 433.03304631 404.02537433]
# controller output torque:  [-0.03095484 -0.56023723 -0.00827007]
# controller output speed:  [406.50258535 428.43419548 433.03304631 404.02537433]
# check output force:  [ 9.78778017 10.8656577  10.98576337  9.73721196]
# desired rotor speed: [404.72451347 426.78850146 428.53470445 403.75746073]
# controller output torque:  [-0.01475098 -0.49350537 -0.00316986]
# controller output speed:  [404.72451347 426.78850146 428.53470445 403.75746073]
# controller output torque:  [-0.01475098 -0.49350537 -0.00316986]
# controller output speed:  [404.72451347 426.78850146 428.53470445 403.75746073]
# controller output torque:  [-0.01475098 -0.49350537 -0.00316986]
# controller output speed:  [404.72451347 426.78850146 428.53470445 403.75746073]
# check output force:  [ 9.57217218 10.68338631 10.59735366  9.51890362]
# desired rotor speed: [402.16677194 425.18680365 423.59214029 401.112026  ]
# controller output torque:  [ 0.02954996 -0.46449346  0.00060851]
# controller output speed:  [402.16677194 425.18680365 423.59214029 401.112026  ]
# controller output torque:  [ 0.02954996 -0.46449346  0.00060851]
# controller output speed:  [402.16677194 425.18680365 423.59214029 401.112026  ]
# controller output torque:  [ 0.02954996 -0.46449346  0.00060851]
# controller output speed:  [402.16677194 425.18680365 423.59214029 401.112026  ]
# check output force:  [ 9.32733404 10.46984154 10.26983978  9.19644847]
# desired rotor speed: [398.94368499 423.11058387 419.6430107  395.88604059]
# controller output torque:  [ 0.07019113 -0.47005862  0.00128367]
# controller output speed:  [398.94368499 423.11058387 419.6430107  395.88604059]
# controller output torque:  [ 0.07019113 -0.47005862  0.00128367]
# controller output speed:  [398.94368499 423.11058387 419.6430107  395.88604059]
# controller output torque:  [ 0.07019113 -0.47005862  0.00128367]
# controller output speed:  [398.94368499 423.11058387 419.6430107  395.88604059]
# check output force:  [ 9.09202545 10.2055828  10.0548482   8.86240958]
# desired rotor speed: [395.29110848 420.2376216  417.50655657 390.10791586]
# controller output torque:  [ 0.08068375 -0.48917093 -0.00146503]
# controller output speed:  [395.29110848 420.2376216  417.50655657 390.10791586]
# controller output torque:  [ 0.08068375 -0.48917093 -0.00146503]
# controller output speed:  [395.29110848 420.2376216  417.50655657 390.10791586]
# controller output torque:  [ 0.08068375 -0.48917093 -0.00146503]
# controller output speed:  [395.29110848 420.2376216  417.50655657 390.10791586]
# check output force:  [8.8891825  9.89968166 9.92676049 8.6105042 ]
# desired rotor speed: [392.35282664 416.70212299 416.77183406 386.06556267]
# controller output torque:  [ 0.05337179 -0.49357464 -0.00567871]
# controller output speed:  [392.35282664 416.70212299 416.77183406 386.06556267]
# controller output torque:  [ 0.05337179 -0.49357464 -0.00567871]
# controller output speed:  [392.35282664 416.70212299 416.77183406 386.06556267]
# controller output torque:  [ 0.05337179 -0.49357464 -0.00567871]
# controller output speed:  [392.35282664 416.70212299 416.77183406 386.06556267]
# check output force:  [8.70916464 9.59978146 9.81966467 8.46877905]
# desired rotor speed: [389.91401149 413.04358175 416.22244727 384.3452653 ]
# controller output torque:  [ 0.00434917 -0.47548991 -0.00854839]
# controller output speed:  [389.91401149 413.04358175 416.22244727 384.3452653 ]
# controller output torque:  [ 0.00434917 -0.47548991 -0.00854839]
# controller output speed:  [389.91401149 413.04358175 416.22244727 384.3452653 ]
# controller output torque:  [ 0.00434917 -0.47548991 -0.00854839]
# controller output speed:  [389.91401149 413.04358175 416.22244727 384.3452653 ]
# check output force:  [8.53815146 9.33158637 9.67257811 8.40613897]
# desired rotor speed: [387.67050094 409.87496727 414.96849802 384.30168489]
# controller output torque:  [-0.04433077 -0.43696109 -0.00878492]
# controller output speed:  [387.67050094 409.87496727 414.96849802 384.30168489]
# controller output torque:  [-0.04433077 -0.43696109 -0.00878492]
# controller output speed:  [387.67050094 409.87496727 414.96849802 384.30168489]
# controller output torque:  [-0.04433077 -0.43696109 -0.00878492]
# controller output speed:  [387.67050094 409.87496727 414.96849802 384.30168489]
# check output force:  [8.36408917 9.10417454 9.47252041 8.35095107]
# desired rotor speed: [385.36151306 407.35127855 412.86003853 384.4392366 ]
# controller output torque:  [-0.07535022 -0.39491281 -0.00708515]
# controller output speed:  [385.36151306 407.35127855 412.86003853 384.4392366 ]
# controller output torque:  [-0.07535022 -0.39491281 -0.00708515]
# controller output speed:  [385.36151306 407.35127855 412.86003853 384.4392366 ]
# controller output torque:  [-0.07535022 -0.39491281 -0.00708515]
# controller output speed:  [385.36151306 407.35127855 412.86003853 384.4392366 ]
# check output force:  [8.18350628 8.91298209 9.23296524 8.24436548]
# desired rotor speed: [382.90894475 405.39484212 410.1073428  383.51754014]
# controller output torque:  [-0.08078809 -0.36445537 -0.00481261]
# controller output speed:  [382.90894475 405.39484212 410.1073428  383.51754014]
# controller output torque:  [-0.08078809 -0.36445537 -0.00481261]
# controller output speed:  [382.90894475 405.39484212 410.1073428  383.51754014]
# controller output torque:  [-0.08078809 -0.36445537 -0.00481261]
# controller output speed:  [382.90894475 405.39484212 410.1073428  383.51754014]
# check output force:  [7.98209082 8.74960429 8.98482156 8.07239684]
# desired rotor speed: [380.00480991 403.8673501  407.2037005  381.22945733]
# controller output torque:  [-0.06905326 -0.35636529 -0.00269138]
# controller output speed:  [380.00480991 403.8673501  407.2037005  381.22945733]
# controller output torque:  [-0.06905326 -0.35636529 -0.00269138]
# controller output speed:  [380.00480991 403.8673501  407.2037005  381.22945733]
# controller output torque:  [-0.06905326 -0.35636529 -0.00269138]
# controller output speed:  [380.00480991 403.8673501  407.2037005  381.22945733]
# check output force:  [7.78051883 8.59124095 8.74837744 7.84331264]
# desired rotor speed: [377.08065621 402.39753562 404.47300034 377.73162509]
# controller output torque:  [-0.04665381 -0.36396988 -0.00175219]
# controller output speed:  [377.08065621 402.39753562 404.47300034 377.73162509]
# controller output torque:  [-0.04665381 -0.36396988 -0.00175219]
# controller output speed:  [377.08065621 402.39753562 404.47300034 377.73162509]
# controller output torque:  [-0.04665381 -0.36396988 -0.00175219]
# controller output speed:  [377.08065621 402.39753562 404.47300034 377.73162509]
# check output force:  [7.5862934  8.43338378 8.53608074 7.57677651]
# desired rotor speed: [374.18103185 400.91182364 402.11424132 373.41301036]
# controller output torque:  [-0.01976629 -0.38319049 -0.0020841 ]
# controller output speed:  [374.18103185 400.91182364 402.11424132 373.41301036]
# controller output torque:  [-0.01976629 -0.38319049 -0.0020841 ]
# controller output speed:  [374.18103185 400.91182364 402.11424132 373.41301036]
# controller output torque:  [-0.01976629 -0.38319049 -0.0020841 ]
# controller output speed:  [374.18103185 400.91182364 402.11424132 373.41301036]
# check output force:  [7.39537001 8.27240534 8.35550112 7.30662607]
# desired rotor speed: [371.17985846 399.13910098 400.24772219 368.73685449]
# controller output torque:  [ 0.00119814 -0.40854337 -0.00319151]
# controller output speed:  [371.17985846 399.13910098 400.24772219 368.73685449]
# controller output torque:  [ 0.00119814 -0.40854337 -0.00319151]
# controller output speed:  [371.17985846 399.13910098 400.24772219 368.73685449]
# controller output torque:  [ 0.00119814 -0.40854337 -0.00319151]
# controller output speed:  [371.17985846 399.13910098 400.24772219 368.73685449]
# check output force:  [7.22207338 8.10409162 8.20305583 7.06566464]
# desired rotor speed: [368.53078198 396.87298603 398.42541352 364.65116717]
# controller output torque:  [ 0.01218571 -0.42837732 -0.00474294]
# controller output speed:  [368.53078198 396.87298603 398.42541352 364.65116717]
# controller output torque:  [ 0.01218571 -0.42837732 -0.00474294]
# controller output speed:  [368.53078198 396.87298603 398.42541352 364.65116717]
# controller output torque:  [ 0.01218571 -0.42837732 -0.00474294]
# controller output speed:  [368.53078198 396.87298603 398.42541352 364.65116717]
# check output force:  [7.07081082 7.91796438 8.08150274 6.89840254]
# desired rotor speed: [366.32597245 394.18132744 397.15670487 362.10673772]
# controller output torque:  [ 0.00188158 -0.43067773 -0.0062394 ]
# controller output speed:  [366.32597245 394.18132744 397.15670487 362.10673772]
# controller output torque:  [ 0.00188158 -0.43067773 -0.0062394 ]
# controller output speed:  [366.32597245 394.18132744 397.15670487 362.10673772]
# controller output torque:  [ 0.00188158 -0.43067773 -0.0062394 ]
# controller output speed:  [366.32597245 394.18132744 397.15670487 362.10673772]
# check output force:  [6.94968609 7.72637516 7.97807469 6.81547911]
# desired rotor speed: [364.73905011 391.32811215 396.24770459 361.34043343]
# controller output torque:  [-0.02492369 -0.41138046 -0.00716729]
# controller output speed:  [364.73905011 391.32811215 396.24770459 361.34043343]
# controller output torque:  [-0.02492369 -0.41138046 -0.00716729]
# controller output speed:  [364.73905011 391.32811215 396.24770459 361.34043343]
# controller output torque:  [-0.02492369 -0.41138046 -0.00716729]
# controller output speed:  [364.73905011 391.32811215 396.24770459 361.34043343]
# check output force:  [6.85241763 7.54373845 7.86989548 6.80666123]
# desired rotor speed: [363.63683274 388.62269042 395.20026012 362.14677154]
# controller output torque:  [-0.05948139 -0.37219377 -0.0069074 ]
# controller output speed:  [363.63683274 388.62269042 395.20026012 362.14677154]
# controller output torque:  [-0.05948139 -0.37219377 -0.0069074 ]
# controller output speed:  [363.63683274 388.62269042 395.20026012 362.14677154]
# controller output torque:  [-0.05948139 -0.37219377 -0.0069074 ]
# controller output speed:  [363.63683274 388.62269042 395.20026012 362.14677154]
# check output force:  [6.76340858 7.40476778 7.71438158 6.82846662]
# desired rotor speed: [362.68584392 386.82189765 393.07821236 363.60488848]
# controller output torque:  [-0.07947914 -0.32398067 -0.00454204]
# controller output speed:  [362.68584392 386.82189765 393.07821236 363.60488848]
# controller output torque:  [-0.07947914 -0.32398067 -0.00454204]
# controller output speed:  [362.68584392 386.82189765 393.07821236 363.60488848]
# controller output torque:  [-0.07947914 -0.32398067 -0.00454204]
# controller output speed:  [362.68584392 386.82189765 393.07821236 363.60488848]
# check output force:  [6.67185124 7.31735919 7.52832089 6.79032515]
# desired rotor speed: [361.6555663  386.09948388 390.24060075 363.76865729]
# controller output torque:  [-0.06988318 -0.29348264 -0.00171774]
# controller output speed:  [361.6555663  386.09948388 390.24060075 363.76865729]
# controller output torque:  [-0.06988318 -0.29348264 -0.00171774]
# controller output speed:  [361.6555663  386.09948388 390.24060075 363.76865729]
# controller output torque:  [-0.06988318 -0.29348264 -0.00171774]
# controller output speed:  [361.6555663  386.09948388 390.24060075 363.76865729]
# check output force:  [6.57110671 7.26712988 7.33416654 6.65689777]
# desired rotor speed: [360.40448434 386.14269752 387.17197232 361.86522771]
# controller output torque:  [-0.03241935 -0.29131642  0.00034832]
# controller output speed:  [360.40448434 386.14269752 387.17197232 361.86522771]
# controller output torque:  [-0.03241935 -0.29131642  0.00034832]
# controller output speed:  [360.40448434 386.14269752 387.17197232 361.86522771]
# controller output torque:  [-0.03241935 -0.29131642  0.00034832]
# controller output speed:  [360.40448434 386.14269752 387.17197232 361.86522771]
# check output force:  [6.47459472 7.22441911 7.17589893 6.43393041]
# desired rotor speed: [359.2241738  386.30450792 384.83634771 357.99807441]
# controller output torque:  [ 1.89187046e-02 -3.16454029e-01  1.45903770e-04]
# controller output speed:  [359.2241738  386.30450792 384.83634771 357.99807441]
# controller output torque:  [ 1.89187046e-02 -3.16454029e-01  1.45903770e-04]
# controller output speed:  [359.2241738  386.30450792 384.83634771 357.99807441]
# controller output torque:  [ 1.89187046e-02 -3.16454029e-01  1.45903770e-04]
# controller output speed:  [359.2241738  386.30450792 384.83634771 357.99807441]
# check output force:  [6.3924369  7.14865511 7.08093319 6.21230951]
# desired rotor speed: [358.33571038 385.70047175 383.84154537 354.11314737]
# controller output torque:  [ 0.05257627 -0.34467771 -0.00208766]
# controller output speed:  [358.33571038 385.70047175 383.84154537 354.11314737]
# controller output torque:  [ 0.05257627 -0.34467771 -0.00208766]
# controller output speed:  [358.33571038 385.70047175 383.84154537 354.11314737]
# controller output torque:  [ 0.05257627 -0.34467771 -0.00208766]
# controller output speed:  [358.33571038 385.70047175 383.84154537 354.11314737]
# check output force:  [6.33743262 7.0263547  7.03459514 6.09510235]
# desired rotor speed: [358.01384072 384.03360944 383.87505867 352.44566625]
# controller output torque:  [ 0.04965747 -0.34543565 -0.00465375]
# controller output speed:  [358.01384072 384.03360944 383.87505867 352.44566625]
# controller output torque:  [ 0.04965747 -0.34543565 -0.00465375]
# controller output speed:  [358.01384072 384.03360944 383.87505867 352.44566625]
# controller output torque:  [ 0.04965747 -0.34543565 -0.00465375]
# controller output speed:  [358.01384072 384.03360944 383.87505867 352.44566625]
# check output force:  [6.31077433 6.87696987 7.00098282 6.11876203]
# desired rotor speed: [358.2824758  381.73313261 384.15403196 353.80404915]
# controller output torque:  [ 0.0144247  -0.30725256 -0.00586941]
# controller output speed:  [358.2824758  381.73313261 384.15403196 353.80404915]
# controller output torque:  [ 0.0144247  -0.30725256 -0.00586941]
# controller output speed:  [358.2824758  381.73313261 384.15403196 353.80404915]
# controller output torque:  [ 0.0144247  -0.30725256 -0.00586941]
# controller output speed:  [358.2824758  381.73313261 384.15403196 353.80404915]
# check output force:  [6.31246675 6.74148819 6.92715203 6.24376964]
# desired rotor speed: [359.14699794 379.70586508 383.50369982 357.35050236]
# controller output torque:  [-0.02481215 -0.23597423 -0.00472415]
# controller output speed:  [359.14699794 379.70586508 383.50369982 357.35050236]
# controller output torque:  [-0.02481215 -0.23597423 -0.00472415]
# controller output speed:  [359.14699794 379.70586508 383.50369982 357.35050236]
# controller output torque:  [-0.02481215 -0.23597423 -0.00472415]
# controller output speed:  [359.14699794 379.70586508 383.50369982 357.35050236]
# check output force:  [6.31873423 6.65042863 6.80756087 6.37763587]
# desired rotor speed: [360.09508118 378.62826485 381.79702947 361.08647902]
# controller output torque:  [-0.04582727 -0.16156232 -0.0018244 ]
# controller output speed:  [360.09508118 378.62826485 381.79702947 361.08647902]
# controller output torque:  [-0.04582727 -0.16156232 -0.0018244 ]
# controller output speed:  [360.09508118 378.62826485 381.79702947 361.08647902]
# controller output torque:  [-0.04582727 -0.16156232 -0.0018244 ]
# controller output speed:  [360.09508118 378.62826485 381.79702947 361.08647902]
# check output force:  [6.31909159 6.60734704 6.66446838 6.43698106]
# desired rotor speed: [360.90327747 378.57859912 379.524873   363.19697124]
# controller output torque:  [-0.03712504 -0.10940451  0.00112862]
# controller output speed:  [360.90327747 378.57859912 379.524873   363.19697124]
# controller output torque:  [-0.03712504 -0.10940451  0.00112862]
# controller output speed:  [360.90327747 378.57859912 379.524873   363.19697124]
# controller output torque:  [-0.03712504 -0.10940451  0.00112862]
# controller output speed:  [360.90327747 378.57859912 379.524873   363.19697124]
# check output force:  [6.3202352  6.58469408 6.53620868 6.40823568]
# desired rotor speed: [361.72272607 378.94159402 377.53924593 363.37951771]
# controller output torque:  [-0.00838233 -0.08324657  0.0025349 ]
# controller output speed:  [361.72272607 378.94159402 377.53924593 363.37951771]
# controller output torque:  [-0.00838233 -0.08324657  0.0025349 ]
# controller output speed:  [361.72272607 378.94159402 377.53924593 363.37951771]
# controller output torque:  [-0.00838233 -0.08324657  0.0025349 ]
# controller output speed:  [361.72272607 378.94159402 377.53924593 363.37951771]
# check output force:  [6.32758795 6.54832373 6.45814318 6.3503153 ]
# desired rotor speed: [362.67532124 378.95322879 376.63045951 362.91620538]
# controller output torque:  [ 0.01430885 -0.06969821  0.00209699]
# controller output speed:  [362.67532124 378.95322879 376.63045951 362.91620538]
# controller output torque:  [ 0.01430885 -0.06969821  0.00209699]
# controller output speed:  [362.67532124 378.95322879 376.63045951 362.91620538]
# controller output torque:  [ 0.01430885 -0.06969821  0.00209699]
# controller output speed:  [362.67532124 378.95322879 376.63045951 362.91620538]
# check output force:  [6.35965971 6.47289795 6.43681222 6.33057173]
# desired rotor speed: [364.1696841  378.04365169 376.94746904 363.28176945]
# controller output torque:  [ 0.0138253  -0.04655802  0.00012997]
# controller output speed:  [364.1696841  378.04365169 376.94746904 363.28176945]
# controller output torque:  [ 0.0138253  -0.04655802  0.00012997]
# controller output speed:  [364.1696841  378.04365169 376.94746904 363.28176945]
# controller output torque:  [ 0.0138253  -0.04655802  0.00012997]
# controller output speed:  [364.1696841  378.04365169 376.94746904 363.28176945]
# check output force:  [6.39781776 6.39010439 6.41590416 6.4151358 ]
# desired rotor speed: [365.79654852 376.92236529 377.2268111  365.93732015]
# controller output torque:  [-0.00914658  0.00147325 -0.00015753]
# controller output speed:  [365.79654852 376.92236529 377.2268111  365.93732015]
# controller output torque:  [-0.00914658  0.00147325 -0.00015753]
# controller output speed:  [365.79654852 376.92236529 377.2268111  365.93732015]
# controller output torque:  [-0.00914658  0.00147325 -0.00015753]
# controller output speed:  [365.79654852 376.92236529 377.2268111  365.93732015]
# check output force:  [6.44958971 6.32664757 6.38348389 6.53930022]
# desired rotor speed: [367.72273635 376.18681298 377.19954329 369.46897086]
# controller output torque:  [-0.03108698  0.05913303  0.00061056]
# controller output speed:  [367.72273635 376.18681298 377.19954329 369.46897086]
# controller output torque:  [-0.03108698  0.05913303  0.00061056]
# controller output speed:  [367.72273635 376.18681298 377.19954329 369.46897086]
# controller output torque:  [-0.03108698  0.05913303  0.00061056]
# controller output speed:  [367.72273635 376.18681298 377.19954329 369.46897086]
# check output force:  [6.49203796 6.30706239 6.32000306 6.65462844]
# desired rotor speed: [369.44292567 376.38760509 376.42250188 372.81507334]
# controller output torque:  [-0.03723542  0.11022295  0.00277939]
# controller output speed:  [369.44292567 376.38760509 376.42250188 372.81507334]
# controller output torque:  [-0.03723542  0.11022295  0.00277939]
# controller output speed:  [369.44292567 376.38760509 376.42250188 372.81507334]
# controller output torque:  [-0.03723542  0.11022295  0.00277939]
# controller output speed:  [369.44292567 376.38760509 376.42250188 372.81507334]
# check output force:  [6.52974005 6.32834411 6.25538219 6.69039154]
# desired rotor speed: [371.05868718 377.4563359  375.56725289 374.41015765]
# controller output torque:  [-0.01860159  0.13500065  0.00433881]
# controller output speed:  [371.05868718 377.4563359  375.56725289 374.41015765]
# controller output torque:  [-0.01860159  0.13500065  0.00433881]
# controller output speed:  [371.05868718 377.4563359  375.56725289 374.41015765]
# controller output torque:  [-0.01860159  0.13500065  0.00433881]
# controller output speed:  [371.05868718 377.4563359  375.56725289 374.41015765]
# check output force:  [6.55469007 6.36405081 6.22229567 6.67022227]
# desired rotor speed: [372.39162572 378.7970771  375.36975198 374.76671947]
# controller output torque:  [0.00556267 0.13545898 0.0047785 ]
# controller output speed:  [372.39162572 378.7970771  375.36975198 374.76671947]
# controller output torque:  [0.00556267 0.13545898 0.0047785 ]
# controller output speed:  [372.39162572 378.7970771  375.36975198 374.76671947]
# controller output torque:  [0.00556267 0.13545898 0.0047785 ]
# controller output speed:  [372.39162572 378.7970771  375.36975198 374.76671947]
# check output force:  [6.59022254 6.37194556 6.24404244 6.64968556]
# desired rotor speed: [373.95686054 379.45574995 376.35767866 375.10632335]
# controller output torque:  [0.0145182  0.13235217 0.00347988]
# controller output speed:  [373.95686054 379.45574995 376.35767866 375.10632335]
# controller output torque:  [0.0145182  0.13235217 0.00347988]
# controller output speed:  [373.95686054 379.45574995 376.35767866 375.10632335]
# controller output torque:  [0.0145182  0.13235217 0.00347988]
# controller output speed:  [373.95686054 379.45574995 376.35767866 375.10632335]
# check output force:  [6.62801345 6.35813648 6.29642833 6.70800447]
# desired rotor speed: [375.56608266 379.57133281 377.98548474 377.18640188]
# controller output torque:  [-0.00387834  0.14455665  0.00263172]
# controller output speed:  [375.56608266 379.57133281 377.98548474 377.18640188]
# controller output torque:  [-0.00387834  0.14455665  0.00263172]
# controller output speed:  [375.56608266 379.57133281 377.98548474 377.18640188]
# controller output torque:  [-0.00387834  0.14455665  0.00263172]
# controller output speed:  [375.56608266 379.57133281 377.98548474 377.18640188]
# check output force:  [6.67555533 6.34332724 6.34472217 6.84430033]
# desired rotor speed: [377.38252106 379.61172351 379.4686986  380.99455148]
# controller output torque:  [-0.03609178  0.17645106  0.00310813]
# controller output speed:  [377.38252106 379.61172351 379.4686986  380.99455148]
# controller output torque:  [-0.03609178  0.17645106  0.00310813]
# controller output speed:  [377.38252106 379.61172351 379.4686986  380.99455148]
# controller output torque:  [-0.03609178  0.17645106  0.00310813]
# controller output speed:  [377.38252106 379.61172351 379.4686986  380.99455148]
# check output force:  [6.7261522  6.35997374 6.36471065 6.99902964]
# desired rotor speed: [379.2549369  380.3106225  380.25975773 385.21277596]
# controller output torque:  [-0.05889033  0.21223553  0.00498007]
# controller output speed:  [379.2549369  380.3106225  380.25975773 385.21277596]
# controller output torque:  [-0.05889033  0.21223553  0.00498007]
# controller output speed:  [379.2549369  380.3106225  380.25975773 385.21277596]
# controller output torque:  [-0.05889033  0.21223553  0.00498007]
# controller output speed:  [379.2549369  380.3106225  380.25975773 385.21277596]
# check output force:  [6.75601652 6.43736136 6.35341017 7.10185538]
# desired rotor speed: [380.65037829 382.33152011 380.29078968 388.27373652]
# controller output torque:  [-0.05555423  0.226364    0.00798232]
# controller output speed:  [380.65037829 382.33152011 380.29078968 388.27373652]
# controller output torque:  [-0.05555423  0.226364    0.00798232]
# controller output speed:  [380.65037829 382.33152011 380.29078968 388.27373652]
# controller output torque:  [-0.05555423  0.226364    0.00798232]
# controller output speed:  [380.65037829 382.33152011 380.29078968 388.27373652]
# check output force:  [6.77958112 6.5434781  6.35747774 7.09694028]
# desired rotor speed: [381.88892096 384.94772302 380.62125366 388.92009636]
# controller output torque:  [-0.02786514  0.20694672  0.0093487 ]
# controller output speed:  [381.88892096 384.94772302 380.62125366 388.92009636]
# controller output torque:  [-0.02786514  0.20694672  0.0093487 ]
# controller output speed:  [381.88892096 384.94772302 380.62125366 388.92009636]
# controller output torque:  [-0.02786514  0.20694672  0.0093487 ]
# controller output speed:  [381.88892096 384.94772302 380.62125366 388.92009636]
# check output force:  [6.79271421 6.65371653 6.39781273 7.02660573]
# desired rotor speed: [382.87441045 387.60436028 381.72573209 388.08163276]
# controller output torque:  [0.00466946 0.16287143 0.00909678]
# controller output speed:  [382.87441045 387.60436028 381.72573209 388.08163276]
# controller output torque:  [0.00466946 0.16287143 0.00909678]
# controller output speed:  [382.87441045 387.60436028 381.72573209 388.08163276]
# controller output torque:  [0.00466946 0.16287143 0.00909678]
# controller output speed:  [382.87441045 387.60436028 381.72573209 388.08163276]
# check output force:  [6.81149681 6.73184632 6.48801979 6.96275199]
# desired rotor speed: [383.96210478 389.48399732 383.91475152 387.35457311]
# controller output torque:  [0.01963716 0.1176012  0.0073377 ]
# controller output speed:  [383.96210478 389.48399732 383.91475152 387.35457311]
# controller output torque:  [0.01963716 0.1176012  0.0073377 ]
# controller output speed:  [383.96210478 389.48399732 383.91475152 387.35457311]
# controller output torque:  [0.01963716 0.1176012  0.0073377 ]
# controller output speed:  [383.96210478 389.48399732 383.91475152 387.35457311]
# check output force:  [6.83994403 6.77876696 6.60592101 6.97223383]
# desired rotor speed: [385.23704725 390.61333596 386.68686657 388.23327589]
# controller output torque:  [0.00860318 0.09068343 0.00566717]
# controller output speed:  [385.23704725 390.61333596 386.68686657 388.23327589]
# controller output torque:  [0.00860318 0.09068343 0.00566717]
# controller output speed:  [385.23704725 390.61333596 386.68686657 388.23327589]
# controller output torque:  [0.00860318 0.09068343 0.00566717]
# controller output speed:  [385.23704725 390.61333596 386.68686657 388.23327589]
# check output force:  [6.8771309  6.81716697 6.71296411 7.05959711]
# desired rotor speed: [386.67456322 391.51206131 389.16965299 390.82362564]
# controller output torque:  [-0.016602    0.08625141  0.00532419]
# controller output speed:  [386.67456322 391.51206131 389.16965299 390.82362564]
# controller output torque:  [-0.016602    0.08625141  0.00532419]
# controller output speed:  [386.67456322 391.51206131 389.16965299 390.82362564]
# controller output torque:  [-0.016602    0.08625141  0.00532419]
# controller output speed:  [386.67456322 391.51206131 389.16965299 390.82362564]
# check output force:  [6.91027101 6.8879272  6.77252097 7.17753895]
# desired rotor speed: [387.98506447 393.11112843 390.53465143 394.06917677]
# controller output torque:  [-0.03221442  0.09065626  0.00710726]
# controller output speed:  [387.98506447 393.11112843 390.53465143 394.06917677]
# controller output torque:  [-0.03221442  0.09065626  0.00710726]
# controller output speed:  [387.98506447 393.11112843 390.53465143 394.06917677]
# controller output torque:  [-0.03221442  0.09065626  0.00710726]
# controller output speed:  [387.98506447 393.11112843 390.53465143 394.06917677]
# check output force:  [6.94385924 6.98563137 6.81180912 7.2474208 ]
# desired rotor speed: [389.270046   395.28656656 391.40570484 396.2029685 ]
# controller output torque:  [-0.0275216   0.08354518  0.00886626]
# controller output speed:  [389.270046   395.28656656 391.40570484 396.2029685 ]
# controller output torque:  [-0.0275216   0.08354518  0.00886626]
# controller output speed:  [389.270046   395.28656656 391.40570484 396.2029685 ]
# controller output torque:  [-0.0275216   0.08354518  0.00886626]
# controller output speed:  [389.270046   395.28656656 391.40570484 396.2029685 ]
# check output force:  [6.96630923 7.10626102 6.85290578 7.25143217]
# desired rotor speed: [390.26930339 397.94858077 392.28719701 396.8204861 ]
# controller output torque:  [-0.00673888  0.05485143  0.01000094]
# controller output speed:  [390.26930339 397.94858077 392.28719701 396.8204861 ]
# controller output torque:  [-0.00673888  0.05485143  0.01000094]
# controller output speed:  [390.26930339 397.94858077 392.28719701 396.8204861 ]
# controller output torque:  [-0.00673888  0.05485143  0.01000094]
# controller output speed:  [390.26930339 397.94858077 392.28719701 396.8204861 ]
# check output force:  [6.98871196 7.20779268 6.92694054 7.22870148]
# desired rotor speed: [391.2329213  400.10784281 393.88858373 396.79761857]
# controller output torque:  [0.00866819 0.01753895 0.00967339]
# controller output speed:  [391.2329213  400.10784281 393.88858373 396.79761857]
# controller output torque:  [0.00866819 0.01753895 0.00967339]
# controller output speed:  [391.2329213  400.10784281 393.88858373 396.79761857]
# controller output torque:  [0.00866819 0.01753895 0.00967339]
# controller output speed:  [391.2329213  400.10784281 393.88858373 396.79761857]
# check output force:  [7.02858488 7.27250473 7.03367238 7.22909066]
# desired rotor speed: [392.55574723 401.09815218 396.20572047 397.25532846]
# controller output torque:  [ 0.00813021 -0.01028864  0.00815965]
# controller output speed:  [392.55574723 401.09815218 396.20572047 397.25532846]
# controller output torque:  [ 0.00813021 -0.01028864  0.00815965]
# controller output speed:  [392.55574723 401.09815218 396.20572047 397.25532846]
# controller output torque:  [ 0.00813021 -0.01028864  0.00815965]
# controller output speed:  [392.55574723 401.09815218 396.20572047 397.25532846]
# check output force:  [7.071211   7.3192134  7.14423624 7.29613242]
# desired rotor speed: [393.90464506 401.76918293 398.58448304 399.17879549]
# controller output torque:  [-0.01059468 -0.02038701  0.00742716]
# controller output speed:  [393.90464506 401.76918293 398.58448304 399.17879549]
# controller output torque:  [-0.01059468 -0.02038701  0.00742716]
# controller output speed:  [393.90464506 401.76918293 398.58448304 399.17879549]
# controller output torque:  [-0.01059468 -0.02038701  0.00742716]
# controller output speed:  [393.90464506 401.76918293 398.58448304 399.17879549]
# check output force:  [7.12216937 7.3823902  7.21705589 7.3932717 ]
# desired rotor speed: [395.40580423 402.70317404 400.06200936 401.29968138]
# controller output torque:  [-0.02243657 -0.01781998  0.00810577]
# controller output speed:  [395.40580423 402.70317404 400.06200936 401.29968138]
# controller output torque:  [-0.02243657 -0.01781998  0.00810577]
# controller output speed:  [395.40580423 402.70317404 400.06200936 401.29968138]
# controller output torque:  [-0.02243657 -0.01781998  0.00810577]
# controller output speed:  [395.40580423 402.70317404 400.06200936 401.29968138]
# check output force:  [7.16874956 7.47221096 7.25580437 7.45864422]
# desired rotor speed: [396.77361724 404.07124286 400.58655189 402.65256996]
# controller output torque:  [-0.01558902 -0.02134485  0.00940333]
# controller output speed:  [396.77361724 404.07124286 400.58655189 402.65256996]
# controller output torque:  [-0.01558902 -0.02134485  0.00940333]
# controller output speed:  [396.77361724 404.07124286 400.58655189 402.65256996]
# controller output torque:  [-0.01558902 -0.02134485  0.00940333]
# controller output speed:  [396.77361724 404.07124286 400.58655189 402.65256996]
# check output force:  [7.20328769 7.59034981 7.27735416 7.44947801]
# desired rotor speed: [397.83738713 405.90194489 400.80800019 402.72825213]
# controller output torque:  [ 0.01417141 -0.04559486  0.01038554]
# controller output speed:  [397.83738713 405.90194489 400.80800019 402.72825213]
# controller output torque:  [ 0.01417141 -0.04559486  0.01038554]
# controller output speed:  [397.83738713 405.90194489 400.80800019 402.72825213]
# controller output torque:  [ 0.01417141 -0.04559486  0.01038554]
# controller output speed:  [397.83738713 405.90194489 400.80800019 402.72825213]
# check output force:  [7.22474716 7.71044784 7.31738477 7.38569872]
# desired rotor speed: [398.57556572 407.75276866 401.32735825 401.8591316 ]
# controller output torque:  [ 0.04923782 -0.08854025  0.0102895 ]
# controller output speed:  [398.57556572 407.75276866 401.32735825 401.8591316 ]
# controller output torque:  [ 0.04923782 -0.08854025  0.0102895 ]
# ...
# controller output torque:  [0.02826739 0.00285654 0.00406384]
# controller output speed:  [259.22888879 264.29417753 261.3642595  259.89854407]
# controller output torque:  [0.02826739 0.00285654 0.00406384]
# controller output speed:  [259.22888879 264.29417753 261.3642595  259.89854407]
# check output force:  [11.73583444 11.74455484 11.69878284 11.76872921]
# desired rotor speed: [261.61061854 265.13283209 264.34818298 262.11972782]
# controller output torque:  [0.00273164 0.01298787 0.00146105]
# controller output speed:  [261.61061854 265.13283209 264.34818298 262.11972782]
# controller output torque:  [0.00273164 0.01298787 0.00146105]
# controller output speed:  [261.61061854 265.13283209 264.34818298 262.11972782]
# controller output torque:  [0.00273164 0.01298787 0.00146105]
# controller output speed:  [261.61061854 265.13283209 264.34818298 262.11972782]
# check output force:  [11.84609537 11.76801237 11.80178194 11.91776092]
# desired rotor speed: [264.14664629 266.24199417 266.77348837 265.28745093]
# controller output torque:  [-0.02236595  0.04116637  0.00070383]
# controller output speed:  [264.14664629 266.24199417 266.77348837 265.28745093]
# controller output torque:  [-0.02236595  0.04116637  0.00070383]
# controller output speed:  [264.14664629 266.24199417 266.77348837 265.28745093]
# controller output torque:  [-0.02236595  0.04116637  0.00070383]
# controller output speed:  [264.14664629 266.24199417 266.77348837 265.28745093]
# check output force:  [11.94329686 11.81950002 11.85024304 12.07193574]
# desired rotor speed: [266.50436903 267.84610735 268.32877003 268.58206198]
# controller output torque:  [-0.03380968  0.07328869  0.00181818]
# controller output speed:  [266.50436903 267.84610735 268.32877003 268.58206198]
# controller output torque:  [-0.03380968  0.07328869  0.00181818]
# controller output speed:  [266.50436903 267.84610735 268.32877003 268.58206198]
# controller output torque:  [-0.03380968  0.07328869  0.00181818]
# controller output speed:  [266.50436903 267.84610735 268.32877003 268.58206198]
# check output force:  [12.02551334 11.89042566 11.84594819 12.18579215]
# desired rotor speed: [268.65146296 269.80352446 269.03312218 271.26067134]
# controller output torque:  [-0.02456494  0.10074725  0.00380286]
# controller output speed:  [268.65146296 269.80352446 269.03312218 271.26067134]
# controller output torque:  [-0.02456494  0.10074725  0.00380286]
# controller output speed:  [268.65146296 269.80352446 269.03312218 271.26067134]
# controller output torque:  [-0.02456494  0.10074725  0.00380286]
# controller output speed:  [268.65146296 269.80352446 269.03312218 271.26067134]
# check output force:  [12.08478616 11.95763048 11.83286035 12.24000186]
# desired rotor speed: [270.45611938 271.7275425  269.61265108 272.99843001]
# controller output torque:  [-0.00645842  0.11334046  0.00520007]
# controller output speed:  [270.45611938 271.7275425  269.61265108 272.99843001]
# controller output torque:  [-0.00645842  0.11334046  0.00520007]
# controller output speed:  [270.45611938 271.7275425  269.61265108 272.99843001]
# controller output torque:  [-0.00645842  0.11334046  0.00520007]
# controller output speed:  [270.45611938 271.7275425  269.61265108 272.99843001]
# check output force:  [12.13135536 12.0106957  11.83875559 12.24735746]
# desired rotor speed: [272.0853132  273.44197347 270.53132431 273.99522749]
# controller output torque:  [0.01186613 0.11227225 0.00534784]
# controller output speed:  [272.0853132  273.44197347 270.53132431 273.99522749]
# controller output torque:  [0.01186613 0.11227225 0.00534784]
# controller output speed:  [272.0853132  273.44197347 270.53132431 273.99522749]
# controller output torque:  [0.01186613 0.11227225 0.00534784]
# controller output speed:  [272.0853132  273.44197347 270.53132431 273.99522749]
# check output force:  [12.17506699 12.03577878 11.88498572 12.24695864]
# desired rotor speed: [273.70090571 274.71088618 272.15243009 274.89023421]
# controller output torque:  [0.01673736 0.10633253 0.00413584]
# controller output speed:  [273.70090571 274.71088618 272.15243009 274.89023421]
# controller output torque:  [0.01673736 0.10633253 0.00413584]
# controller output speed:  [273.70090571 274.71088618 272.15243009 274.89023421]
# controller output torque:  [0.01673736 0.10633253 0.00413584]
# controller output speed:  [273.70090571 274.71088618 272.15243009 274.89023421]
# check output force:  [12.2212608  12.05483198 11.95074432 12.25954354]
# desired rotor speed: [275.39092019 275.9023143  274.13023992 276.02668311]
# controller output torque:  [0.0139592  0.10081012 0.00264419]
# controller output speed:  [275.39092019 275.9023143  274.13023992 276.02668311]
# controller output torque:  [0.0139592  0.10081012 0.00264419]
# controller output speed:  [275.39092019 275.9023143  274.13023992 276.02668311]
# controller output torque:  [0.0139592  0.10081012 0.00264419]
# controller output speed:  [275.39092019 275.9023143  274.13023992 276.02668311]
# check output force:  [12.26758113 12.07405253 12.00817537 12.29615599]
# desired rotor speed: [277.11534715 277.12083227 275.99425488 277.59181686]
# controller output torque:  [0.00791294 0.10214255 0.00175422]
# controller output speed:  [277.11534715 277.12083227 275.99425488 277.59181686]
# controller output torque:  [0.00791294 0.10214255 0.00175422]
# controller output speed:  [277.11534715 277.12083227 275.99425488 277.59181686]
# controller output torque:  [0.00791294 0.10214255 0.00175422]
# controller output speed:  [277.11534715 277.12083227 275.99425488 277.59181686]
# check output force:  [12.30510829 12.102015   12.04340943 12.33844685]
# desired rotor speed: [278.72316358 278.51281491 277.50583941 279.28167567]
# controller output torque:  [0.00535989 0.10566847 0.00170764]
# controller output speed:  [278.72316358 278.51281491 277.50583941 279.28167567]
# controller output torque:  [0.00535989 0.10566847 0.00170764]
# controller output speed:  [278.72316358 278.51281491 277.50583941 279.28167567]
# controller output torque:  [0.00535989 0.10566847 0.00170764]
# controller output speed:  [278.72316358 278.51281491 277.50583941 279.28167567]
# check output force:  [12.33282381 12.13680012 12.06197793 12.36236067]
# desired rotor speed: [280.19479941 280.04652124 278.75549744 280.69045364]
# controller output torque:  [0.00960638 0.1053027  0.00193822]
# controller output speed:  [280.19479941 280.04652124 278.75549744 280.69045364]
# controller output torque:  [0.00960638 0.1053027  0.00193822]
# controller output speed:  [280.19479941 280.04652124 278.75549744 280.69045364]
# controller output torque:  [0.00960638 0.1053027  0.00193822]
# controller output speed:  [280.19479941 280.04652124 278.75549744 280.69045364]
# check output force:  [12.34897656 12.1689338  12.08176698 12.37771587]
# desired rotor speed: [281.49794124 281.55974225 280.04810553 281.98032383]
# controller output torque:  [0.01239423 0.10097211 0.00215268]
# controller output speed:  [281.49794124 281.55974225 280.04810553 281.98032383]
# controller output torque:  [0.01239423 0.10097211 0.00215268]
# controller output speed:  [281.49794124 281.55974225 280.04810553 281.98032383]
# controller output torque:  [0.01239423 0.10097211 0.00215268]
# controller output speed:  [281.49794124 281.55974225 280.04810553 281.98032383]
# check output force:  [12.37322753 12.1774283  12.13745778 12.39135368]
# desired rotor speed: [282.96512844 282.6880277  281.9851386  283.26515064]
# controller output torque:  [0.00463385 0.09539383 0.00107901]
# controller output speed:  [282.96512844 282.6880277  281.9851386  283.26515064]
# controller output torque:  [0.00463385 0.09539383 0.00107901]
# controller output speed:  [282.96512844 282.6880277  281.9851386  283.26515064]
# controller output torque:  [0.00463385 0.09539383 0.00107901]
# controller output speed:  [282.96512844 282.6880277  281.9851386  283.26515064]
# check output force:  [12.40568623 12.17438284 12.2137299  12.43150942]
# desired rotor speed: [284.59887727 283.63641362 284.30844391 285.02884341]
# controller output torque:  [-0.01382457  0.09526396 -0.00025117]
# controller output speed:  [284.59887727 283.63641362 284.30844391 285.02884341]
# controller output torque:  [-0.01382457  0.09526396 -0.00025117]
# controller output speed:  [284.59887727 283.63641362 284.30844391 285.02884341]
# controller output torque:  [-0.01382457  0.09526396 -0.00025117]
# controller output speed:  [284.59887727 283.63641362 284.30844391 285.02884341]
# check output force:  [12.44541742 12.17484901 12.28114815 12.49673778]
# desired rotor speed: [286.38366114 284.66433731 286.50914433 287.25389693]
# controller output torque:  [-0.03343583  0.10312871 -0.0010211 ]
# controller output speed:  [286.38366114 284.66433731 286.50914433 287.25389693]
# controller output torque:  [-0.03343583  0.10312871 -0.0010211 ]
# controller output speed:  [286.38366114 284.66433731 286.50914433 287.25389693]
# controller output torque:  [-0.03343583  0.10312871 -0.0010211 ]
# controller output speed:  [286.38366114 284.66433731 286.50914433 287.25389693]
# check output force:  [12.46561905 12.20908544 12.29148798 12.56474889]
# desired rotor speed: [287.8559699  286.30264944 287.73885589 289.56218644]
# controller output torque:  [-0.03850846  0.11238531  0.00031067]
# controller output speed:  [287.8559699  286.30264944 287.73885589 289.56218644]
# controller output torque:  [-0.03850846  0.11238531  0.00031067]
# controller output speed:  [287.8559699  286.30264944 287.73885589 289.56218644]
# controller output torque:  [-0.03850846  0.11238531  0.00031067]
# controller output speed:  [287.8559699  286.30264944 287.73885589 289.56218644]
# check output force:  [12.46047981 12.27101081 12.23935723 12.58537809]
# desired rotor speed: [288.90984533 288.45096075 287.88857195 291.08178608]
# controller output torque:  [-0.01978     0.11359346  0.00290758]
# controller output speed:  [288.90984533 288.45096075 287.88857195 291.08178608]
# controller output torque:  [-0.01978     0.11359346  0.00290758]
# controller output speed:  [288.90984533 288.45096075 287.88857195 291.08178608]
# controller output torque:  [-0.01978     0.11359346  0.00290758]
# controller output speed:  [288.90984533 288.45096075 287.88857195 291.08178608]
# check output force:  [12.4270605  12.33309668 12.16316698 12.5284225 ]
# desired rotor speed: [289.48804452 290.6512779  287.6423749  291.27001423]
# controller output torque:  [0.01454527 0.0974142  0.00503859]
# controller output speed:  [289.48804452 290.6512779  287.6423749  291.27001423]
# controller output torque:  [0.01454527 0.0974142  0.00503859]
# controller output speed:  [289.48804452 290.6512779  287.6423749  291.27001423]
# controller output torque:  [0.01454527 0.0974142  0.00503859]
# controller output speed:  [289.48804452 290.6512779  287.6423749  291.27001423]
# check output force:  [12.38226297 12.36734013 12.12558224 12.40445515]
# desired rotor speed: [289.88136558 292.62541093 288.33035642 290.28832515]
# controller output torque:  [0.04657647 0.06232289 0.00490224]
# controller output speed:  [289.88136558 292.62541093 288.33035642 290.28832515]
# controller output torque:  [0.04657647 0.06232289 0.00490224]
# controller output speed:  [289.88136558 292.62541093 288.33035642 290.28832515]
# controller output torque:  [0.04657647 0.06232289 0.00490224]
# controller output speed:  [289.88136558 292.62541093 288.33035642 290.28832515]
# check output force:  [12.33963445 12.35384668 12.17153487 12.28577578]
# desired rotor speed: [290.32621558 293.77864362 290.52802794 289.39241554]
# controller output torque:  [0.05009884 0.02121909 0.00238571]
# controller output speed:  [290.32621558 293.77864362 290.52802794 289.39241554]
# controller output torque:  [0.05009884 0.02121909 0.00238571]
# controller output speed:  [290.32621558 293.77864362 290.52802794 289.39241554]
# controller output torque:  [0.05009884 0.02121909 0.00238571]
# controller output speed:  [290.32621558 293.77864362 290.52802794 289.39241554]
# check output force:  [12.33579637 12.29485643 12.29645334 12.23221146]
# desired rotor speed: [291.76607674 294.14199134 294.18070267 289.93409156]
# controller output torque:  [ 0.02163471 -0.00494304 -0.0019535 ]
# controller output speed:  [291.76607674 294.14199134 294.18070267 289.93409156]
# controller output torque:  [ 0.02163471 -0.00494304 -0.0019535 ]
# controller output speed:  [291.76607674 294.14199134 294.18070267 289.93409156]
# controller output torque:  [ 0.02163471 -0.00494304 -0.0019535 ]
# controller output speed:  [291.76607674 294.14199134 294.18070267 289.93409156]
# check output force:  [12.36055236 12.23359898 12.43501808 12.28727888]
# desired rotor speed: [293.73791129 294.48751752 298.13655901 292.42602672]
# controller output torque:  [-0.02718353 -0.00440929 -0.00510176]
# controller output speed:  [293.73791129 294.48751752 298.13655901 292.42602672]
# controller output torque:  [-0.02718353 -0.00440929 -0.00510176]
# controller output speed:  [293.73791129 294.48751752 298.13655901 292.42602672]
# controller output torque:  [-0.02718353 -0.00440929 -0.00510176]
# controller output speed:  [293.73791129 294.48751752 298.13655901 292.42602672]
# check output force:  [12.39681939 12.20790177 12.50749474 12.41597925]
# desired rotor speed: [295.93679031 295.49947848 300.75806726 296.27452006]
# controller output torque:  [-0.06761704  0.02066191 -0.00520837]
# controller output speed:  [295.93679031 295.49947848 300.75806726 296.27452006]
# controller output torque:  [-0.06761704  0.02066191 -0.00520837]
# controller output speed:  [295.93679031 295.49947848 300.75806726 296.27452006]
# controller output torque:  [-0.06761704  0.02066191 -0.00520837]
# controller output speed:  [295.93679031 295.49947848 300.75806726 296.27452006]
# check output force:  [12.41194604 12.24334358 12.45798485 12.54321474]
# desired rotor speed: [297.77605888 297.65274464 301.25686777 300.12174218]
# controller output torque:  [-0.07337788  0.05384546 -0.00154845]
# controller output speed:  [297.77605888 297.65274464 301.25686777 300.12174218]
# controller output torque:  [-0.07337788  0.05384546 -0.00154845]
# controller output speed:  [297.77605888 297.65274464 301.25686777 300.12174218]
# controller output torque:  [-0.07337788  0.05384546 -0.00154845]
# controller output speed:  [297.77605888 297.65274464 301.25686777 300.12174218]
# check output force:  [12.39206248 12.31332792 12.32389992 12.56712805]
# desired rotor speed: [299.00050449 300.37374073 300.53975431 301.75772175]
# controller output torque:  [-0.0393793   0.06829794  0.00305507]
# controller output speed:  [299.00050449 300.37374073 300.53975431 301.75772175]
# controller output torque:  [-0.0393793   0.06829794  0.00305507]
# controller output speed:  [299.00050449 300.37374073 300.53975431 301.75772175]
# controller output torque:  [-0.0393793   0.06829794  0.00305507]
# controller output speed:  [299.00050449 300.37374073 300.53975431 301.75772175]
# check output force:  [12.32547787 12.38487387 12.17185222 12.47304558]
# desired rotor speed: [299.38847387 302.64250424 299.44850526 301.69317593]
# controller output torque:  [0.01388474 0.05129248 0.00669708]
# controller output speed:  [299.38847387 302.64250424 299.44850526 301.69317593]
# controller output torque:  [0.01388474 0.05129248 0.00669708]
# controller output speed:  [299.38847387 302.64250424 299.44850526 301.69317593]
# controller output torque:  [0.01388474 0.05129248 0.00669708]
# controller output speed:  [299.38847387 302.64250424 299.44850526 301.69317593]
# check output force:  [12.25696206 12.39754621 12.10028776 12.28969676]
# desired rotor speed: [299.75221879 304.06491246 299.70583456 300.33063043]
# controller output torque:  [0.05611342 0.01035721 0.00612883]
# controller output speed:  [299.75221879 304.06491246 299.70583456 300.33063043]
# controller output torque:  [0.05611342 0.01035721 0.00612883]
# controller output speed:  [299.75221879 304.06491246 299.70583456 300.33063043]
# controller output torque:  [0.05611342 0.01035721 0.00612883]
# controller output speed:  [299.75221879 304.06491246 299.70583456 300.33063043]
# Sim data is written into:
# ..\data\training\test_wind_near_wall_x0_0_y0_0_z4_0_d1_4_validation_no_bemt.csv

# %% [markdown]
# Optionally, save the header index into a file for future reference.

# %%
sim_test.logger.generate_column_map()
