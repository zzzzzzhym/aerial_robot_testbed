# %% [markdown]
# # MuJoCo Simulation Guideline
# - Model XML: `falling_box.xml`
# - Simulation class: `mujoco_world.py` (`MujocoWorld`, `setup_camera`)
# - Entry point: `mujoco_user_execution.py`

# %%
# %run mujoco_user_execution.py
